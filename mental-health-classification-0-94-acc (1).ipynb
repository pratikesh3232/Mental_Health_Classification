# %% [markdown]
# # Importing Library

# %%
import numpy as np
import pandas as pd
import os
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split


from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import SGDClassifier
from catboost import CatBoostClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/playground-series-s4e11/sample_submission.csv
# /kaggle/input/playground-series-s4e11/train.csv
# /kaggle/input/playground-series-s4e11/test.csv

# %%
# !pip install git+https://github.com/AutoViML/Auto_ViML.git
# !pip install ipykernel==5.5.6
# !pip install --upgrade pandas
# !pip install scipy==1.11.0

# %% [markdown]
# # Dataset|

# %%
df=pd.read_csv('/kaggle/input/playground-series-s4e11/train.csv',index_col=['id'])
df.head()
# Out:
#         Name  Gender   Age           City Working Professional or Student  \
# id
# 0   Aaradhya  Female  49.0       Ludhiana            Working Professional
# 1      Vivan    Male  26.0       Varanasi            Working Professional
# 2     Yuvraj    Male  33.0  Visakhapatnam                         Student
# 3     Yuvraj    Male  22.0         Mumbai            Working Professional
# 4       Rhea  Female  30.0         Kanpur            Working Professional
#
#           Profession  Academic Pressure  Work Pressure  CGPA  \
# id
# 0               Chef                NaN            5.0   NaN
# 1            Teacher                NaN            4.0   NaN
# 2                NaN                5.0            NaN  8.97
# 3            Teacher                NaN            5.0   NaN
# 4   Business Analyst                NaN            1.0   NaN
#
#     Study Satisfaction  Job Satisfaction     Sleep Duration Dietary Habits  \
# id
# 0                  NaN               2.0  More than 8 hours        Healthy
# 1                  NaN               3.0  Less than 5 hours      Unhealthy
# 2                  2.0               NaN          5-6 hours        Healthy
# 3                  NaN               1.0  Less than 5 hours       Moderate
# 4                  NaN               1.0          5-6 hours      Unhealthy
#
#      Degree Have you ever had suicidal thoughts ?  Work/Study Hours  \
# id
# 0       BHM                                    No               1.0
# 1       LLB                                   Yes               7.0
# 2   B.Pharm                                   Yes               3.0
# 3       BBA                                   Yes              10.0
# 4       BBA                                   Yes               9.0
#
#     Financial Stress Family History of Mental Illness  Depression
# id
# 0                2.0                               No           0
# 1                3.0                               No           1
# 2                1.0                               No           1
# 3                1.0                              Yes           1
# 4                4.0                              Yes           0

# %%
df.columns
# Out:
# Index(['Name', 'Gender', 'Age', 'City', 'Working Professional or Student',
#        'Profession', 'Academic Pressure', 'Work Pressure', 'CGPA',
#        'Study Satisfaction', 'Job Satisfaction', 'Sleep Duration',
#        'Dietary Habits', 'Degree', 'Have you ever had suicidal thoughts ?',
#        'Work/Study Hours', 'Financial Stress',
#        'Family History of Mental Illness', 'Depression'],
#       dtype='object')

# %%
df.describe()
# Out:
#                  Age  Academic Pressure  Work Pressure          CGPA  \
# count  140700.000000       27897.000000  112782.000000  27898.000000
# mean       40.388621           3.142273       2.998998      7.658636
# std        12.384099           1.380457       1.405771      1.464466
# min        18.000000           1.000000       1.000000      5.030000
# 25%        29.000000           2.000000       2.000000      6.290000
# 50%        42.000000           3.000000       3.000000      7.770000
# 75%        51.000000           4.000000       4.000000      8.920000
# max        60.000000           5.000000       5.000000     10.000000
#
#        Study Satisfaction  Job Satisfaction  Work/Study Hours  \
# count        27897.000000     112790.000000     140700.000000
# mean             2.944940          2.974404          6.252679
# std              1.360197          1.416078          3.853615
# min              1.000000          1.000000          0.000000
# 25%              2.000000          2.000000          3.000000
# 50%              3.000000          3.000000          6.000000
# 75%              4.000000          4.000000         10.000000
# max              5.000000          5.000000         12.000000
#
#        Financial Stress     Depression
# count     140696.000000  140700.000000
# mean           2.988983       0.181713
# std            1.413633       0.385609
# min            1.000000       0.000000
# 25%            2.000000       0.000000
# 50%            3.000000       0.000000
# 75%            4.000000       0.000000
# max            5.000000       1.000000

# %%
df.shape
# Out:
# (140700, 19)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 140700 entries, 0 to 140699
# Data columns (total 19 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   Name                                   140700 non-null  object
#  1   Gender                                 140700 non-null  object
#  2   Age                                    140700 non-null  float64
#  3   City                                   140700 non-null  object
#  4   Working Professional or Student        140700 non-null  object
#  5   Profession                             104070 non-null  object
#  6   Academic Pressure                      27897 non-null   float64
#  7   Work Pressure                          112782 non-null  float64
#  8   CGPA                                   27898 non-null   float64
#  9   Study Satisfaction                     27897 non-null   float64
#  10  Job Satisfaction                       112790 non-null  float64
#  11  Sleep Duration                         140700 non-null  object
#  12  Dietary Habits                         140696 non-null  object
#  13  Degree                                 140698 non-null  object
#  14  Have you ever had suicidal thoughts ?  140700 non-null  object
#  15  Work/Study Hours                       140700 non-null  float64
#  16  Financial Stress                       140696 non-null  float64
#  17  Family History of Mental Illness       140700 non-null  object
#  18  Depression                             140700 non-null  int64
# dtypes: float64(8), int64(1), object(10)
# memory usage: 21.5+ MB

# %% [markdown]
# ++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# # Data Processing

# %%
# Standardize column names
df.columns = df.columns.str.strip().str.replace(" ", "_").str.lower()

# %%
df.isnull().sum()
# Out:
# name                                          0
# gender                                        0
# age                                           0
# city                                          0
# working_professional_or_student               0
# profession                                36630
# academic_pressure                        112803
# work_pressure                             27918
# cgpa                                     112802
# study_satisfaction                       112803
# job_satisfaction                          27910
# sleep_duration                                0
# dietary_habits                                4
# degree                                        2
# have_you_ever_had_suicidal_thoughts_?         0
# work/study_hours                              0
# financial_stress                              4
# family_history_of_mental_illness              0
# depression                                    0
# dtype: int64

# %% [markdown]
# ### **Cleaning "Profession" Column**

# %%
df[df['profession'].isna()]
# Out:
#              name  gender   age           city  \
# id
# 2          Yuvraj    Male  33.0  Visakhapatnam
# 8       Aishwarya  Female  24.0      Bangalore
# 26         Aditya    Male  31.0       Srinagar
# 29        Kashish  Female  19.0           Agra
# 30         Prisha  Female  28.0       Varanasi
# ...           ...     ...   ...            ...
# 140686      Rohan    Male  27.0       Ludhiana
# 140689      Ayaan    Male  31.0      Faridabad
# 140690      Rashi  Female  18.0       Ludhiana
# 140695      Vidya  Female  18.0      Ahmedabad
# 140699        Sai    Male  27.0          Patna
#
#        working_professional_or_student profession  academic_pressure  \
# id
# 2                              Student        NaN                5.0
# 8                              Student        NaN                2.0
# 26                             Student        NaN                3.0
# 29                Working Professional        NaN                NaN
# 30                             Student        NaN                3.0
# ...                                ...        ...                ...
# 140686                         Student        NaN                2.0
# 140689                         Student        NaN                3.0
# 140690                         Student        NaN                5.0
# 140695            Working Professional        NaN                NaN
# 140699                         Student        NaN                4.0
#
#         work_pressure  cgpa  study_satisfaction  job_satisfaction  \
# id
# 2                 NaN  8.97                 2.0               NaN
# 8                 NaN  5.90                 5.0               NaN
# 26                NaN  7.03                 5.0               NaN
# 29                1.0   NaN                 NaN               5.0
# 30                NaN  5.59                 2.0               NaN
# ...               ...   ...                 ...               ...
# 140686            NaN  9.40                 3.0               NaN
# 140689            NaN  6.61                 4.0               NaN
# 140690            NaN  6.88                 2.0               NaN
# 140695            5.0   NaN                 NaN               4.0
# 140699            NaN  9.24                 1.0               NaN
#
#            sleep_duration dietary_habits    degree  \
# id
# 2               5-6 hours        Healthy   B.Pharm
# 8               5-6 hours       Moderate       BSc
# 26      Less than 5 hours        Healthy        BA
# 29      More than 8 hours        Healthy  Class 12
# 30              7-8 hours       Moderate       BCA
# ...                   ...            ...       ...
# 140686  Less than 5 hours        Healthy       MSc
# 140689          5-6 hours      Unhealthy        MD
# 140690  Less than 5 hours        Healthy  Class 12
# 140695          5-6 hours      Unhealthy  Class 12
# 140699  Less than 5 hours        Healthy       BCA
#
#        have_you_ever_had_suicidal_thoughts_?  work/study_hours  \
# id
# 2                                        Yes               3.0
# 8                                         No               3.0
# 26                                        No               9.0
# 29                                        No               5.0
# 30                                       Yes               4.0
# ...                                      ...               ...
# 140686                                    No               0.0
# 140689                                    No              12.0
# 140690                                   Yes              10.0
# 140695                                    No               2.0
# 140699                                   Yes               2.0
#
#         financial_stress family_history_of_mental_illness  depression
# id
# 2                    1.0                               No           1
# 8                    2.0                              Yes           0
# 26                   1.0                              Yes           0
# 29                   2.0                               No           0
# 30                   5.0                              Yes           1
# ...                  ...                              ...         ...
# 140686               3.0                              Yes           0
# 140689               2.0                               No           0
# 140690               5.0                               No           1
# 140695               4.0                              Yes           1
# 140699               3.0                              Yes           1
#
# [36630 rows x 19 columns]

# %%
df.loc[df['working_professional_or_student'] == "Student", 'profession'] = df.loc[df['working_professional_or_student'] == "Student", 'profession'].fillna('Student')

# %% [markdown]
#  **Cleaned "profeesion" to `Student` where "working_professional_or_student"  is `Student`  **

# %% [markdown]
# ###  Cleaning "**Academic_pressure**" Column

# %%
df[df['academic_pressure'].isna()]
# Out:
#             name  gender   age       city working_professional_or_student  \
# id
# 0       Aaradhya  Female  49.0   Ludhiana            Working Professional
# 1          Vivan    Male  26.0   Varanasi            Working Professional
# 3         Yuvraj    Male  22.0     Mumbai            Working Professional
# 4           Rhea  Female  30.0     Kanpur            Working Professional
# 5           Vani  Female  59.0  Ahmedabad            Working Professional
# ...          ...     ...   ...        ...                             ...
# 140694   Ishaani  Female  45.0  Ahmedabad            Working Professional
# 140695     Vidya  Female  18.0  Ahmedabad            Working Professional
# 140696      Lata  Female  41.0  Hyderabad            Working Professional
# 140697   Aanchal  Female  24.0    Kolkata            Working Professional
# 140698    Prachi  Female  49.0   Srinagar            Working Professional
#
#                  profession  academic_pressure  work_pressure  cgpa  \
# id
# 0                      Chef                NaN            5.0   NaN
# 1                   Teacher                NaN            4.0   NaN
# 3                   Teacher                NaN            5.0   NaN
# 4          Business Analyst                NaN            1.0   NaN
# 5       Finanancial Analyst                NaN            2.0   NaN
# ...                     ...                ...            ...   ...
# 140694              Teacher                NaN            2.0   NaN
# 140695                  NaN                NaN            5.0   NaN
# 140696       Content Writer                NaN            5.0   NaN
# 140697    Marketing Manager                NaN            3.0   NaN
# 140698              Plumber                NaN            5.0   NaN
#
#         study_satisfaction  job_satisfaction     sleep_duration  \
# id
# 0                      NaN               2.0  More than 8 hours
# 1                      NaN               3.0  Less than 5 hours
# 3                      NaN               1.0  Less than 5 hours
# 4                      NaN               1.0          5-6 hours
# 5                      NaN               5.0          5-6 hours
# ...                    ...               ...                ...
# 140694                 NaN               5.0  Less than 5 hours
# 140695                 NaN               4.0          5-6 hours
# 140696                 NaN               4.0          7-8 hours
# 140697                 NaN               1.0  More than 8 hours
# 140698                 NaN               2.0          5-6 hours
#
#        dietary_habits    degree have_you_ever_had_suicidal_thoughts_?  \
# id
# 0             Healthy       BHM                                    No
# 1           Unhealthy       LLB                                   Yes
# 3            Moderate       BBA                                   Yes
# 4           Unhealthy       BBA                                   Yes
# 5             Healthy       MCA                                    No
# ...               ...       ...                                   ...
# 140694       Moderate      B.Ed                                   Yes
# 140695      Unhealthy  Class 12                                    No
# 140696       Moderate    B.Tech                                   Yes
# 140697       Moderate     B.Com                                    No
# 140698       Moderate        ME                                   Yes
#
#         work/study_hours  financial_stress family_history_of_mental_illness  \
# id
# 0                    1.0               2.0                               No
# 1                    7.0               3.0                               No
# 3                   10.0               1.0                              Yes
# 4                    9.0               4.0                              Yes
# 5                    7.0               5.0                               No
# ...                  ...               ...                              ...
# 140694               1.0               5.0                               No
# 140695               2.0               4.0                              Yes
# 140696               6.0               5.0                              Yes
# 140697               4.0               4.0                               No
# 140698              10.0               1.0                               No
#
#         depression
# id
# 0                0
# 1                1
# 3                1
# 4                0
# 5                0
# ...            ...
# 140694           0
# 140695           1
# 140696           0
# 140697           0
# 140698           0
#
# [112803 rows x 19 columns]

# %% [markdown]
# **Setting "academic_pressure" to `0.0` Where "working_professional_or_student" is `Working Professional`**

# %%
df.loc[df['working_professional_or_student'] == "Working Professional", 'academic_pressure'] = df.loc[df['working_professional_or_student'] == "Working Professional", 'academic_pressure'].fillna(0.0)

# %% [markdown]
# **Setting "academic_pressure"  `NaN` to mean Value Where "working_professional_or_student" is `student`**

# %%
df.loc[df['working_professional_or_student'] == "Student", 'academic_pressure'] = df.loc[df['working_professional_or_student'] == "Student", 'academic_pressure'].fillna(df['academic_pressure'].mean())

# %% [markdown]
# ### Cleaning "Work_pressure" Column

# %%
df[df['work_pressure'].isna()]
# Out:
#              name  gender   age           city  \
# id
# 2          Yuvraj    Male  33.0  Visakhapatnam
# 8       Aishwarya  Female  24.0      Bangalore
# 26         Aditya    Male  31.0       Srinagar
# 30         Prisha  Female  28.0       Varanasi
# 32         Chhavi  Female  25.0         Jaipur
# ...           ...     ...   ...            ...
# 140685   Aaradhya  Female  27.0          Surat
# 140686      Rohan    Male  27.0       Ludhiana
# 140689      Ayaan    Male  31.0      Faridabad
# 140690      Rashi  Female  18.0       Ludhiana
# 140699        Sai    Male  27.0          Patna
#
#        working_professional_or_student profession  academic_pressure  \
# id
# 2                              Student    Student                5.0
# 8                              Student    Student                2.0
# 26                             Student    Student                3.0
# 30                             Student    Student                3.0
# 32                             Student    Student                4.0
# ...                                ...        ...                ...
# 140685                         Student    Student                5.0
# 140686                         Student    Student                2.0
# 140689                         Student    Student                3.0
# 140690                         Student    Student                5.0
# 140699                         Student    Student                4.0
#
#         work_pressure  cgpa  study_satisfaction  job_satisfaction  \
# id
# 2                 NaN  8.97                 2.0               NaN
# 8                 NaN  5.90                 5.0               NaN
# 26                NaN  7.03                 5.0               NaN
# 30                NaN  5.59                 2.0               NaN
# 32                NaN  8.13                 3.0               NaN
# ...               ...   ...                 ...               ...
# 140685            NaN  5.75                 5.0               NaN
# 140686            NaN  9.40                 3.0               NaN
# 140689            NaN  6.61                 4.0               NaN
# 140690            NaN  6.88                 2.0               NaN
# 140699            NaN  9.24                 1.0               NaN
#
#            sleep_duration dietary_habits    degree  \
# id
# 2               5-6 hours        Healthy   B.Pharm
# 8               5-6 hours       Moderate       BSc
# 26      Less than 5 hours        Healthy        BA
# 30              7-8 hours       Moderate       BCA
# 32              5-6 hours       Moderate    M.Tech
# ...                   ...            ...       ...
# 140685          5-6 hours      Unhealthy  Class 12
# 140686  Less than 5 hours        Healthy       MSc
# 140689          5-6 hours      Unhealthy        MD
# 140690  Less than 5 hours        Healthy  Class 12
# 140699  Less than 5 hours        Healthy       BCA
#
#        have_you_ever_had_suicidal_thoughts_?  work/study_hours  \
# id
# 2                                        Yes               3.0
# 8                                         No               3.0
# 26                                        No               9.0
# 30                                       Yes               4.0
# 32                                       Yes               1.0
# ...                                      ...               ...
# 140685                                   Yes               7.0
# 140686                                    No               0.0
# 140689                                    No              12.0
# 140690                                   Yes              10.0
# 140699                                   Yes               2.0
#
#         financial_stress family_history_of_mental_illness  depression
# id
# 2                    1.0                               No           1
# 8                    2.0                              Yes           0
# 26                   1.0                              Yes           0
# 30                   5.0                              Yes           1
# 32                   1.0                               No           0
# ...                  ...                              ...         ...
# 140685               1.0                              Yes           0
# 140686               3.0                              Yes           0
# 140689               2.0                               No           0
# 140690               5.0                               No           1
# 140699               3.0                              Yes           1
#
# [27918 rows x 19 columns]

# %% [markdown]
# **Setting "Work_pressure" to `0.0` Where "working_professional_or_student" is `Student|`**

# %%
df.loc[df['working_professional_or_student'] == "Student", 'work_pressure'] = df.loc[df['working_professional_or_student'] == "Student", 'work_pressure'].fillna(0.0)

# %%
df[df['work_pressure'].isna()]
# Out:
#              name  gender   age           city  \
# id
# 15846       Shrey    Male  53.0    Vasai-Virar
# 18752       Aarti  Female  18.0         Kalyan
# 34694       Kriti  Female  46.0         Meerut
# 35612    Siddhesh    Male  27.0       Vadodara
# 41915      Advait    Male  18.0        Kolkata
# 55827      Prachi  Female  19.0         Kalyan
# 57196       Manvi  Female  20.0  Visakhapatnam
# 60348     Nishant    Male  29.0           Agra
# 76104       Vanya  Female  20.0         Nashik
# 85126      Monika  Female  27.0         Kanpur
# 86606      Tushar    Male  18.0          Thane
# 92609      Shruti  Female  51.0         Indore
# 93213       Anika  Female  23.0         Kanpur
# 98446      Ritika  Female  54.0          Surat
# 99062     Tanisha  Female  24.0          Surat
# 100868     Harsha    Male  29.0         Nashik
# 101189     Keshav    Male  34.0         Rajkot
# 122793       Amit    Male  20.0           Pune
# 125384     Harini  Female  18.0       Vadodara
# 134154  Siddharth    Male  34.0           Pune
#
#        working_professional_or_student           profession  \
# id
# 15846             Working Professional                  NaN
# 18752             Working Professional                  NaN
# 34694             Working Professional                  NaN
# 35612             Working Professional                  NaN
# 41915             Working Professional                  NaN
# 55827             Working Professional                  NaN
# 57196             Working Professional                  NaN
# 60348             Working Professional                  NaN
# 76104             Working Professional                  NaN
# 85126             Working Professional  Mechanical Engineer
# 86606             Working Professional                  NaN
# 92609             Working Professional                  NaN
# 93213             Working Professional                  NaN
# 98446             Working Professional                  NaN
# 99062             Working Professional       Content Writer
# 100868            Working Professional                  NaN
# 101189            Working Professional                  NaN
# 122793            Working Professional                  NaN
# 125384            Working Professional                  NaN
# 134154            Working Professional                  NaN
#
#         academic_pressure  work_pressure  cgpa  study_satisfaction  \
# id
# 15846                 0.0            NaN   NaN                 NaN
# 18752                 2.0            NaN  8.14                 5.0
# 34694                 0.0            NaN   NaN                 NaN
# 35612                 0.0            NaN   NaN                 NaN
# 41915                 4.0            NaN  8.04                 3.0
# 55827                 3.0            NaN  8.11                 2.0
# 57196                 0.0            NaN   NaN                 NaN
# 60348                 0.0            NaN  9.72                 2.0
# 76104                 0.0            NaN   NaN                 NaN
# 85126                 0.0            NaN   NaN                 NaN
# 86606                 0.0            NaN   NaN                 NaN
# 92609                 0.0            NaN   NaN                 NaN
# 93213                 0.0            NaN   NaN                 NaN
# 98446                 0.0            NaN   NaN                 NaN
# 99062                 4.0            NaN  5.42                 4.0
# 100868                0.0            NaN   NaN                 NaN
# 101189                4.0            NaN  8.24                 3.0
# 122793                0.0            NaN   NaN                 NaN
# 125384                0.0            NaN   NaN                 NaN
# 134154                0.0            NaN   NaN                 NaN
#
#         job_satisfaction     sleep_duration dietary_habits    degree  \
# id
# 15846                5.0  More than 8 hours      Unhealthy  Class 12
# 18752                NaN  Less than 5 hours        Healthy  Class 12
# 34694                NaN          5-6 hours       Moderate  Class 12
# 35612                NaN  Less than 5 hours      Unhealthy   B.Pharm
# 41915                NaN          5-6 hours        Healthy  Class 12
# 55827                NaN          5-6 hours      Unhealthy  Class 12
# 57196                NaN  Less than 5 hours       Moderate  Class 12
# 60348                NaN          5-6 hours       Moderate      B.Ed
# 76104                1.0          7-8 hours       Moderate  Class 12
# 85126                5.0          5-6 hours        Healthy        BE
# 86606                1.0          7-8 hours       Moderate  Class 12
# 92609                2.0          7-8 hours        Healthy  Class 12
# 93213                4.0  More than 8 hours       Moderate       MSc
# 98446                NaN  More than 8 hours       Moderate  Class 12
# 99062                NaN  Less than 5 hours       Moderate      B.Ed
# 100868               NaN  More than 8 hours        Healthy       BHM
# 101189               NaN  More than 8 hours       Moderate        MD
# 122793               NaN          5-6 hours        Healthy  Class 12
# 125384               4.0          7-8 hours        Healthy  Class 12
# 134154               4.0          5-6 hours       Moderate  Class 12
#
#        have_you_ever_had_suicidal_thoughts_?  work/study_hours  \
# id
# 15846                                     No              12.0
# 18752                                    Yes               7.0
# 34694                                    Yes              12.0
# 35612                                     No              11.0
# 41915                                    Yes               1.0
# 55827                                    Yes               4.0
# 57196                                     No               0.0
# 60348                                     No               7.0
# 76104                                     No              11.0
# 85126                                    Yes              10.0
# 86606                                    Yes              10.0
# 92609                                    Yes               4.0
# 93213                                     No               2.0
# 98446                                    Yes               0.0
# 99062                                    Yes               1.0
# 100868                                   Yes              10.0
# 101189                                    No              11.0
# 122793                                    No               0.0
# 125384                                   Yes               9.0
# 134154                                    No               4.0
#
#         financial_stress family_history_of_mental_illness  depression
# id
# 15846                1.0                               No           0
# 18752                1.0                              Yes           1
# 34694                3.0                               No           0
# 35612                3.0                               No           1
# 41915                5.0                              Yes           1
# 55827                4.0                               No           1
# 57196                4.0                              Yes           1
# 60348                2.0                              Yes           0
# 76104                1.0                               No           1
# 85126                5.0                               No           1
# 86606                3.0                               No           1
# 92609                5.0                              Yes           0
# 93213                1.0                              Yes           0
# 98446                4.0                               No           0
# 99062                5.0                               No           1
# 100868               3.0                               No           0
# 101189               1.0                               No           0
# 122793               5.0                               No           0
# 125384               4.0                               No           1
# 134154               5.0                               No           0

# %% [markdown]
# **Setting "academic_pressure" `NaN` to mean Value Where "working_professional_or_student" is `Student`**

# %%
df.loc[df['working_professional_or_student'] == "Working Professional", 'work_pressure'] = df.loc[df['working_professional_or_student'] == "Working Professional", 'work_pressure'].fillna(df['work_pressure'].mean())

# %%
df[df['study_satisfaction'].isna()]
# Out:
#             name  gender   age       city working_professional_or_student  \
# id
# 0       Aaradhya  Female  49.0   Ludhiana            Working Professional
# 1          Vivan    Male  26.0   Varanasi            Working Professional
# 3         Yuvraj    Male  22.0     Mumbai            Working Professional
# 4           Rhea  Female  30.0     Kanpur            Working Professional
# 5           Vani  Female  59.0  Ahmedabad            Working Professional
# ...          ...     ...   ...        ...                             ...
# 140694   Ishaani  Female  45.0  Ahmedabad            Working Professional
# 140695     Vidya  Female  18.0  Ahmedabad            Working Professional
# 140696      Lata  Female  41.0  Hyderabad            Working Professional
# 140697   Aanchal  Female  24.0    Kolkata            Working Professional
# 140698    Prachi  Female  49.0   Srinagar            Working Professional
#
#                  profession  academic_pressure  work_pressure  cgpa  \
# id
# 0                      Chef                0.0            5.0   NaN
# 1                   Teacher                0.0            4.0   NaN
# 3                   Teacher                0.0            5.0   NaN
# 4          Business Analyst                0.0            1.0   NaN
# 5       Finanancial Analyst                0.0            2.0   NaN
# ...                     ...                ...            ...   ...
# 140694              Teacher                0.0            2.0   NaN
# 140695                  NaN                0.0            5.0   NaN
# 140696       Content Writer                0.0            5.0   NaN
# 140697    Marketing Manager                0.0            3.0   NaN
# 140698              Plumber                0.0            5.0   NaN
#
#         study_satisfaction  job_satisfaction     sleep_duration  \
# id
# 0                      NaN               2.0  More than 8 hours
# 1                      NaN               3.0  Less than 5 hours
# 3                      NaN               1.0  Less than 5 hours
# 4                      NaN               1.0          5-6 hours
# 5                      NaN               5.0          5-6 hours
# ...                    ...               ...                ...
# 140694                 NaN               5.0  Less than 5 hours
# 140695                 NaN               4.0          5-6 hours
# 140696                 NaN               4.0          7-8 hours
# 140697                 NaN               1.0  More than 8 hours
# 140698                 NaN               2.0          5-6 hours
#
#        dietary_habits    degree have_you_ever_had_suicidal_thoughts_?  \
# id
# 0             Healthy       BHM                                    No
# 1           Unhealthy       LLB                                   Yes
# 3            Moderate       BBA                                   Yes
# 4           Unhealthy       BBA                                   Yes
# 5             Healthy       MCA                                    No
# ...               ...       ...                                   ...
# 140694       Moderate      B.Ed                                   Yes
# 140695      Unhealthy  Class 12                                    No
# 140696       Moderate    B.Tech                                   Yes
# 140697       Moderate     B.Com                                    No
# 140698       Moderate        ME                                   Yes
#
#         work/study_hours  financial_stress family_history_of_mental_illness  \
# id
# 0                    1.0               2.0                               No
# 1                    7.0               3.0                               No
# 3                   10.0               1.0                              Yes
# 4                    9.0               4.0                              Yes
# 5                    7.0               5.0                               No
# ...                  ...               ...                              ...
# 140694               1.0               5.0                               No
# 140695               2.0               4.0                              Yes
# 140696               6.0               5.0                              Yes
# 140697               4.0               4.0                               No
# 140698              10.0               1.0                               No
#
#         depression
# id
# 0                0
# 1                1
# 3                1
# 4                0
# 5                0
# ...            ...
# 140694           0
# 140695           1
# 140696           0
# 140697           0
# 140698           0
#
# [112803 rows x 19 columns]

# %% [markdown]
# **Setting "Study_satisifcation" to `0.0` Where "working_professional_or_student" is `Working Professional`**

# %%
df.loc[df['working_professional_or_student'] == "Working Professional", 'study_satisfaction'] = df.loc[df['working_professional_or_student'] == "Working Professional", 'study_satisfaction'].fillna(0.0)
df.loc[df['working_professional_or_student'] == "Student", 'study_satisfaction'] = df.loc[df['working_professional_or_student'] == "Student", 'study_satisfaction'].fillna(df['study_satisfaction'].mean())

# %%
df['study_satisfaction'].isna().sum()
# Out:
# 0

# %%
df[df['job_satisfaction'].isna()]
# Out:
#              name  gender   age           city  \
# id
# 2          Yuvraj    Male  33.0  Visakhapatnam
# 8       Aishwarya  Female  24.0      Bangalore
# 26         Aditya    Male  31.0       Srinagar
# 30         Prisha  Female  28.0       Varanasi
# 32         Chhavi  Female  25.0         Jaipur
# ...           ...     ...   ...            ...
# 140685   Aaradhya  Female  27.0          Surat
# 140686      Rohan    Male  27.0       Ludhiana
# 140689      Ayaan    Male  31.0      Faridabad
# 140690      Rashi  Female  18.0       Ludhiana
# 140699        Sai    Male  27.0          Patna
#
#        working_professional_or_student profession  academic_pressure  \
# id
# 2                              Student    Student                5.0
# 8                              Student    Student                2.0
# 26                             Student    Student                3.0
# 30                             Student    Student                3.0
# 32                             Student    Student                4.0
# ...                                ...        ...                ...
# 140685                         Student    Student                5.0
# 140686                         Student    Student                2.0
# 140689                         Student    Student                3.0
# 140690                         Student    Student                5.0
# 140699                         Student    Student                4.0
#
#         work_pressure  cgpa  study_satisfaction  job_satisfaction  \
# id
# 2                 0.0  8.97                 2.0               NaN
# 8                 0.0  5.90                 5.0               NaN
# 26                0.0  7.03                 5.0               NaN
# 30                0.0  5.59                 2.0               NaN
# 32                0.0  8.13                 3.0               NaN
# ...               ...   ...                 ...               ...
# 140685            0.0  5.75                 5.0               NaN
# 140686            0.0  9.40                 3.0               NaN
# 140689            0.0  6.61                 4.0               NaN
# 140690            0.0  6.88                 2.0               NaN
# 140699            0.0  9.24                 1.0               NaN
#
#            sleep_duration dietary_habits    degree  \
# id
# 2               5-6 hours        Healthy   B.Pharm
# 8               5-6 hours       Moderate       BSc
# 26      Less than 5 hours        Healthy        BA
# 30              7-8 hours       Moderate       BCA
# 32              5-6 hours       Moderate    M.Tech
# ...                   ...            ...       ...
# 140685          5-6 hours      Unhealthy  Class 12
# 140686  Less than 5 hours        Healthy       MSc
# 140689          5-6 hours      Unhealthy        MD
# 140690  Less than 5 hours        Healthy  Class 12
# 140699  Less than 5 hours        Healthy       BCA
#
#        have_you_ever_had_suicidal_thoughts_?  work/study_hours  \
# id
# 2                                        Yes               3.0
# 8                                         No               3.0
# 26                                        No               9.0
# 30                                       Yes               4.0
# 32                                       Yes               1.0
# ...                                      ...               ...
# 140685                                   Yes               7.0
# 140686                                    No               0.0
# 140689                                    No              12.0
# 140690                                   Yes              10.0
# 140699                                   Yes               2.0
#
#         financial_stress family_history_of_mental_illness  depression
# id
# 2                    1.0                               No           1
# 8                    2.0                              Yes           0
# 26                   1.0                              Yes           0
# 30                   5.0                              Yes           1
# 32                   1.0                               No           0
# ...                  ...                              ...         ...
# 140685               1.0                              Yes           0
# 140686               3.0                              Yes           0
# 140689               2.0                               No           0
# 140690               5.0                               No           1
# 140699               3.0                              Yes           1
#
# [27910 rows x 19 columns]

# %% [markdown]
# **Setting "job_satisfication" to `0.0` Where "working_professional_or_student" is `Working Professional`**

# %%
df.loc[df['working_professional_or_student'] == "Student", 'job_satisfaction'] = df.loc[df['working_professional_or_student'] == "Student", 'job_satisfaction'].fillna(0.0)
df.loc[df['working_professional_or_student'] == "Working Professional", 'job_satisfaction'] = df.loc[df['working_professional_or_student'] == "Working Professional", 'job_satisfaction'].fillna(df['job_satisfaction'].mean())

# %% [markdown]
# **Dropping Remaining `Null` Values**

# %%
df.dropna(subset=['profession', 'dietary_habits','degree','financial_stress'], inplace=True)

# %%
df.head()
# Out:
#         name  gender   age           city working_professional_or_student  \
# id
# 0   Aaradhya  Female  49.0       Ludhiana            Working Professional
# 1      Vivan    Male  26.0       Varanasi            Working Professional
# 2     Yuvraj    Male  33.0  Visakhapatnam                         Student
# 3     Yuvraj    Male  22.0         Mumbai            Working Professional
# 4       Rhea  Female  30.0         Kanpur            Working Professional
#
#           profession  academic_pressure  work_pressure  cgpa  \
# id
# 0               Chef                0.0            5.0   NaN
# 1            Teacher                0.0            4.0   NaN
# 2            Student                5.0            0.0  8.97
# 3            Teacher                0.0            5.0   NaN
# 4   Business Analyst                0.0            1.0   NaN
#
#     study_satisfaction  job_satisfaction     sleep_duration dietary_habits  \
# id
# 0                  0.0               2.0  More than 8 hours        Healthy
# 1                  0.0               3.0  Less than 5 hours      Unhealthy
# 2                  2.0               0.0          5-6 hours        Healthy
# 3                  0.0               1.0  Less than 5 hours       Moderate
# 4                  0.0               1.0          5-6 hours      Unhealthy
#
#      degree have_you_ever_had_suicidal_thoughts_?  work/study_hours  \
# id
# 0       BHM                                    No               1.0
# 1       LLB                                   Yes               7.0
# 2   B.Pharm                                   Yes               3.0
# 3       BBA                                   Yes              10.0
# 4       BBA                                   Yes               9.0
#
#     financial_stress family_history_of_mental_illness  depression
# id
# 0                2.0                               No           0
# 1                3.0                               No           1
# 2                1.0                               No           1
# 3                1.0                              Yes           1
# 4                4.0                              Yes           0

# %% [markdown]
# **Changing Dtype of "Age" to `Float` to `Int`**

# %%
df['age']=df['age'].astype('int')

# %% [markdown]
# **function for Value_counts**

# %%
def VC(col):
    for c in col:
        print(df[c].value_counts())
        print("\t  = = = = = = = = = = = = = = = = = = = \t")

# %%
VC(['city','working_professional_or_student','profession','dietary_habits','sleep_duration','degree','have_you_ever_had_suicidal_thoughts_?'])
# Out:
# city
# Kalyan         6294
# Patna          5663
# Vasai-Virar    5387
# Kolkata        5327
# Meerut         5271
#                ...
# Moreadhyay        1
# Morena            1
# Ishkarsh          1
# Kashk             1
# Malyansh          1
# Name: count, Length: 97, dtype: int64
# 	  = = = = = = = = = = = = = = = = = = =
# working_professional_or_student
# Working Professional    104034
# Student                  27896
# Name: count, dtype: int64
# 	  = = = = = = = = = = = = = = = = = = =
# profession
# Student           27869
# Teacher           24906
# Content Writer     7814
# Architect          4370
# Consultant         4228
#                   ...
# Moderate              1
# Analyst               1
# Pranav                1
# Visakhapatnam         1
# Yuvraj                1
# Name: count, Length: 64, dtype: int64
# 	  = = = = = = = = = = = = = = = = = = =
# dietary_habits
# Moderate             46891
# Unhealthy            42793
# Healthy              42224
# Yes                      2
# No                       2
# BSc                      1
# Pratham                  1
# Gender                   1
# 3                        1
# Less than Healthy        1
# More Healthy             1
# 1.0                      1
# Hormonal                 1
# Electrician              1
# Mihir                    1
# No Healthy               1
# Less Healthy             1
# M.Tech                   1
# Vegas                    1
# Male                     1
# Indoor                   1
# Class 12                 1
# 2                        1
# Name: count, dtype: int64
# 	  = = = = = = = = = = = = = = = = = = =
# sleep_duration
# Less than 5 hours    35873
# 7-8 hours            34918
# More than 8 hours    30824
# 5-6 hours            30238
# 3-4 hours               11
# 6-7 hours                8
# 4-5 hours                7
# 4-6 hours                5
# 2-3 hours                5
# 6-8 hours                4
# 1-6 hours                4
# No                       4
# 8-9 hours                2
# Sleep_Duration           2
# 10-11 hours              2
# Unhealthy                2
# 45                       2
# 9-11 hours               2
# 1-2 hours                1
# 9-6 hours                1
# 55-66 hours              1
# Moderate                 1
# 40-45 hours              1
# 1-3 hours                1
# 35-36 hours              1
# 8 hours                  1
# Indore                   1
# 10-6 hours               1
# than 5 hours             1
# Work_Study_Hours         1
# 3-6 hours                1
# 45-48 hours              1
# 9-5                      1
# Pune                     1
# 9-5 hours                1
# Name: count, dtype: int64
# 	  = = = = = = = = = = = = = = = = = = =
# degree
# B.Ed        11679
# B.Arch       8729
# B.Com        8107
# Class 12     6139
# B.Pharm      5851
#             ...
# 29              1
# LLCom           1
# 0               1
# Bhavesh         1
# 5.61            1
# Name: count, Length: 112, dtype: int64
# 	  = = = = = = = = = = = = = = = = = = =
# have_you_ever_had_suicidal_thoughts_?
# No     67411
# Yes    64519
# Name: count, dtype: int64
# 	  = = = = = = = = = = = = = = = = = = =

# %% [markdown]
# **Removing the Categories which has less than 10 Value_counts**

# %%
city_counts = df['city'].value_counts()
threshold = 10
cities_to_keep = city_counts[city_counts > threshold].index
df = df[df['city'].isin(cities_to_keep)]

# %%
degree_counts = df['degree'].value_counts()
threshold = 10
Degree_to_keep = degree_counts[degree_counts > threshold].index
df = df[df['degree'].isin(Degree_to_keep)]

# %%
profession_counts = df['profession'].value_counts()
threshold = 10
profession_to_keep = profession_counts[profession_counts > threshold].index
df = df[df['profession'].isin(profession_to_keep)]

# %%
# Cleaning `sleep_duration`
# Define a map to consolidate ranges
sleep_map = {
    'Less than 5 hours': '0-5 hours',
    'More than 8 hours': '8+ hours',
    '3-4 hours': '0-5 hours',
    '5-6 hours': '5-6 hours',
    '7-8 hours': '7-8 hours',
    # Add more mappings as needed
}
df['sleep_duration'] = df['sleep_duration'].replace(sleep_map)

valid_sleep = ['0-5 hours', '8+ hours', '5-6 hours','7-8 hours']
df['sleep_duration'] = df['sleep_duration'].where(df['sleep_duration'].isin(valid_sleep))

# %%
# Cleaning `dietary_habits`
# Drop unrelated or incorrect entries
valid_diet = ['Healthy', 'Unhealthy', 'Moderate']
df['dietary_habits'] = df['dietary_habits'].where(df['dietary_habits'].isin(valid_diet))

# %%
df.head()
# Out:
#         name  gender  age           city working_professional_or_student  \
# id
# 0   Aaradhya  Female   49       Ludhiana            Working Professional
# 1      Vivan    Male   26       Varanasi            Working Professional
# 2     Yuvraj    Male   33  Visakhapatnam                         Student
# 3     Yuvraj    Male   22         Mumbai            Working Professional
# 4       Rhea  Female   30         Kanpur            Working Professional
#
#           profession  academic_pressure  work_pressure  cgpa  \
# id
# 0               Chef                0.0            5.0   NaN
# 1            Teacher                0.0            4.0   NaN
# 2            Student                5.0            0.0  8.97
# 3            Teacher                0.0            5.0   NaN
# 4   Business Analyst                0.0            1.0   NaN
#
#     study_satisfaction  job_satisfaction sleep_duration dietary_habits  \
# id
# 0                  0.0               2.0       8+ hours        Healthy
# 1                  0.0               3.0      0-5 hours      Unhealthy
# 2                  2.0               0.0      5-6 hours        Healthy
# 3                  0.0               1.0      0-5 hours       Moderate
# 4                  0.0               1.0      5-6 hours      Unhealthy
#
#      degree have_you_ever_had_suicidal_thoughts_?  work/study_hours  \
# id
# 0       BHM                                    No               1.0
# 1       LLB                                   Yes               7.0
# 2   B.Pharm                                   Yes               3.0
# 3       BBA                                   Yes              10.0
# 4       BBA                                   Yes               9.0
#
#     financial_stress family_history_of_mental_illness  depression
# id
# 0                2.0                               No           0
# 1                3.0                               No           1
# 2                1.0                               No           1
# 3                1.0                              Yes           1
# 4                4.0                              Yes           0

# %% [markdown]
# ### Now Evrything is Clean And Good For Modeling

# %% [markdown]
# ## Label Encoding

# %%
col = ['degree','profession','city','dietary_habits','gender','working_professional_or_student','sleep_duration','have_you_ever_had_suicidal_thoughts_?','family_history_of_mental_illness']


def label_encode(df, column_name):
    le = LabelEncoder()
    for col in column_name:
        df[col] = le.fit_transform(df[col])
    return df

# %%
label_encode(df,col)
# Out:
#             name  gender  age  city  working_professional_or_student  \
# id
# 0       Aaradhya       0   49    15                                1
# 1          Vivan       1   26    27                                1
# 2         Yuvraj       1   33    29                                0
# 3         Yuvraj       1   22    17                                1
# 4           Rhea       0   30    12                                1
# ...          ...     ...  ...   ...                              ...
# 140694   Ishaani       0   45     1                                1
# 140696      Lata       0   41     8                                1
# 140697   Aanchal       0   24    13                                1
# 140698    Prachi       0   49    23                                1
# 140699       Sai       1   27    20                                0
#
#         profession  academic_pressure  work_pressure  cgpa  \
# id
# 0                3                0.0            5.0   NaN
# 1               33                0.0            4.0   NaN
# 2               32                5.0            0.0  8.97
# 3               33                0.0            5.0   NaN
# 4                2                0.0            1.0   NaN
# ...            ...                ...            ...   ...
# 140694          33                0.0            2.0   NaN
# 140696           7                0.0            5.0   NaN
# 140697          23                0.0            3.0   NaN
# 140698          27                0.0            5.0   NaN
# 140699          32                4.0            0.0  9.24
#
#         study_satisfaction  job_satisfaction  sleep_duration  dietary_habits  \
# id
# 0                      0.0               2.0               3               0
# 1                      0.0               3.0               0               2
# 2                      2.0               0.0               1               0
# 3                      0.0               1.0               0               1
# 4                      0.0               1.0               1               2
# ...                    ...               ...             ...             ...
# 140694                 0.0               5.0               0               1
# 140696                 0.0               4.0               2               1
# 140697                 0.0               1.0               3               1
# 140698                 0.0               2.0               1               1
# 140699                 1.0               0.0               0               0
#
#         degree  have_you_ever_had_suicidal_thoughts_?  work/study_hours  \
# id
# 0            9                                      0               1.0
# 1           12                                      1               7.0
# 2            3                                      1               3.0
# 3            6                                      1              10.0
# 4            6                                      1               9.0
# ...        ...                                    ...               ...
# 140694       2                                      1               1.0
# 140696       4                                      1               6.0
# 140697       1                                      0               4.0
# 140698      23                                      1              10.0
# 140699       7                                      1               2.0
#
#         financial_stress  family_history_of_mental_illness  depression
# id
# 0                    2.0                                 0           0
# 1                    3.0                                 0           1
# 2                    1.0                                 0           1
# 3                    1.0                                 1           1
# 4                    4.0                                 1           0
# ...                  ...                               ...         ...
# 140694               5.0                                 0           0
# 140696               5.0                                 1           0
# 140697               4.0                                 0           0
# 140698               1.0                                 0           0
# 140699               3.0                                 1           1
#
# [131685 rows x 19 columns]

# %%
df_copy = df.copy()

# %% [markdown]
# # Test Data

# %%
test=pd.read_csv('/kaggle/input/playground-series-s4e11/test.csv',index_col=['id'])
test.head()
# Out:
#            Name  Gender   Age           City Working Professional or Student  \
# id
# 140700   Shivam    Male  53.0  Visakhapatnam            Working Professional
# 140701    Sanya  Female  58.0        Kolkata            Working Professional
# 140702     Yash    Male  53.0         Jaipur            Working Professional
# 140703   Nalini  Female  23.0         Rajkot                         Student
# 140704  Shaurya    Male  47.0         Kalyan            Working Professional
#
#                     Profession  Academic Pressure  Work Pressure  CGPA  \
# id
# 140700                   Judge                NaN            2.0   NaN
# 140701  Educational Consultant                NaN            2.0   NaN
# 140702                 Teacher                NaN            4.0   NaN
# 140703                     NaN                5.0            NaN  6.84
# 140704                 Teacher                NaN            5.0   NaN
#
#         Study Satisfaction  Job Satisfaction     Sleep Duration  \
# id
# 140700                 NaN               5.0  Less than 5 hours
# 140701                 NaN               4.0  Less than 5 hours
# 140702                 NaN               1.0          7-8 hours
# 140703                 1.0               NaN  More than 8 hours
# 140704                 NaN               5.0          7-8 hours
#
#        Dietary Habits  Degree Have you ever had suicidal thoughts ?  \
# id
# 140700       Moderate     LLB                                    No
# 140701       Moderate    B.Ed                                    No
# 140702       Moderate  B.Arch                                   Yes
# 140703       Moderate     BSc                                   Yes
# 140704       Moderate     BCA                                   Yes
#
#         Work/Study Hours  Financial Stress Family History of Mental Illness
# id
# 140700               9.0               3.0                              Yes
# 140701               6.0               4.0                               No
# 140702              12.0               4.0                               No
# 140703              10.0               4.0                               No
# 140704               3.0               4.0                               No

# %% [markdown]
# ### **Did Same processing as for Train Data**

# %%
# Standardize column names
test.columns = test.columns.str.strip().str.replace(" ", "_").str.lower()

# %%
test.loc[test['working_professional_or_student'] == "Student", 'profession'] = test.loc[test['working_professional_or_student'] == "Student", 'profession'].fillna('Student')

# %%
test[test['academic_pressure'].isna()]
# Out:
#            name  gender   age           city working_professional_or_student  \
# id
# 140700   Shivam    Male  53.0  Visakhapatnam            Working Professional
# 140701    Sanya  Female  58.0        Kolkata            Working Professional
# 140702     Yash    Male  53.0         Jaipur            Working Professional
# 140704  Shaurya    Male  47.0         Kalyan            Working Professional
# 140705   Kartik    Male  29.0         Mumbai            Working Professional
# ...         ...     ...   ...            ...                             ...
# 234492   Advait    Male  23.0          Delhi            Working Professional
# 234495     Zoya  Female  49.0         Jaipur            Working Professional
# 234496    Shlok    Male  29.0      Ahmedabad            Working Professional
# 234498   Eshita  Female  23.0         Kalyan            Working Professional
# 234499    Gauri  Female  43.0       Varanasi            Working Professional
#
#                     profession  academic_pressure  work_pressure  cgpa  \
# id
# 140700                   Judge                NaN            2.0   NaN
# 140701  Educational Consultant                NaN            2.0   NaN
# 140702                 Teacher                NaN            4.0   NaN
# 140704                 Teacher                NaN            5.0   NaN
# 140705        Customer Support                NaN            2.0   NaN
# ...                        ...                ...            ...   ...
# 234492              Consultant                NaN            2.0   NaN
# 234495                   Pilot                NaN            3.0   NaN
# 234496                   Pilot                NaN            5.0   NaN
# 234498       Marketing Manager                NaN            4.0   NaN
# 234499  Educational Consultant                NaN            5.0   NaN
#
#         study_satisfaction  job_satisfaction     sleep_duration  \
# id
# 140700                 NaN               5.0  Less than 5 hours
# 140701                 NaN               4.0  Less than 5 hours
# 140702                 NaN               1.0          7-8 hours
# 140704                 NaN               5.0          7-8 hours
# 140705                 NaN               3.0  More than 8 hours
# ...                    ...               ...                ...
# 234492                 NaN               3.0  Less than 5 hours
# 234495                 NaN               5.0  Less than 5 hours
# 234496                 NaN               1.0          7-8 hours
# 234498                 NaN               2.0          5-6 hours
# 234499                 NaN               2.0  More than 8 hours
#
#        dietary_habits  degree have_you_ever_had_suicidal_thoughts_?  \
# id
# 140700       Moderate     LLB                                    No
# 140701       Moderate    B.Ed                                    No
# 140702       Moderate  B.Arch                                   Yes
# 140704       Moderate     BCA                                   Yes
# 140705       Moderate   B.Com                                    No
# ...               ...     ...                                   ...
# 234492       Moderate   B.Com                                   Yes
# 234495       Moderate     BSc                                   Yes
# 234496       Moderate      BE                                   Yes
# 234498        Healthy      BA                                   Yes
# 234499        Healthy    B.Ed                                    No
#
#         work/study_hours  financial_stress family_history_of_mental_illness
# id
# 140700               9.0               3.0                              Yes
# 140701               6.0               4.0                               No
# 140702              12.0               4.0                               No
# 140704               3.0               4.0                               No
# 140705               3.0               2.0                              Yes
# ...                  ...               ...                              ...
# 234492              12.0               4.0                               No
# 234495               2.0               2.0                              Yes
# 234496              11.0               3.0                              Yes
# 234498               7.0               5.0                              Yes
# 234499              11.0               2.0                               No
#
# [75033 rows x 18 columns]

# %%
test.loc[test['working_professional_or_student'] == "Working Professional", 'academic_pressure'] = test.loc[test['working_professional_or_student'] == "Working Professional", 'academic_pressure'].fillna(0.0)

# %%
test.loc[test['working_professional_or_student'] == "Student", 'academic_pressure'] = test.loc[test['working_professional_or_student'] == "Student", 'academic_pressure'].fillna(test['academic_pressure'].mean())

# %%
test.loc[test['working_professional_or_student'] == "Student", 'academic_pressure'].isna().sum()
# Out:
# 0

# %%
test[test['work_pressure'].isna()]
# Out:
#             name  gender   age           city working_professional_or_student  \
# id
# 140703    Nalini  Female  23.0         Rajkot                         Student
# 140708     Navya  Female  21.0          Surat                         Student
# 140719     Kiran    Male  28.0        Lucknow                         Student
# 140720     Rashi  Female  26.0      Ghaziabad                         Student
# 140721     Manan    Male  32.0  Visakhapatnam                         Student
# ...          ...     ...   ...            ...                             ...
# 234485    Ishaan    Male  33.0           Agra                         Student
# 234490  Abhishek    Male  19.0         Nashik                         Student
# 234493      Aohi  Female  29.0       Vadodara                         Student
# 234494     Shlok    Male  33.0         Nashik                         Student
# 234497     Rishi    Male  24.0  Visakhapatnam                         Student
#
#        profession  academic_pressure  work_pressure  cgpa  study_satisfaction  \
# id
# 140703    Student                5.0            NaN  6.84                 1.0
# 140708    Student                1.0            NaN  7.39                 3.0
# 140719    Student                5.0            NaN  6.03                 3.0
# 140720    Student                3.0            NaN  8.63                 5.0
# 140721    Student                3.0            NaN  8.61                 1.0
# ...           ...                ...            ...   ...                 ...
# 234485    Student                5.0            NaN  5.74                 2.0
# 234490    Student                4.0            NaN  8.96                 3.0
# 234493    Student                2.0            NaN  5.58                 5.0
# 234494    Student                1.0            NaN  7.92                 2.0
# 234497    Student                1.0            NaN  7.51                 4.0
#
#         job_satisfaction     sleep_duration dietary_habits    degree  \
# id
# 140703               NaN  More than 8 hours       Moderate       BSc
# 140708               NaN  Less than 5 hours        Healthy       BBA
# 140719               NaN          7-8 hours       Moderate        MA
# 140720               NaN  More than 8 hours       Moderate       BBA
# 140721               NaN  Less than 5 hours       Moderate      M.Ed
# ...                  ...                ...            ...       ...
# 234485               NaN          7-8 hours       Moderate     B.Com
# 234490               NaN          7-8 hours      Unhealthy  Class 12
# 234493               NaN  More than 8 hours        Healthy  Class 12
# 234494               NaN  More than 8 hours        Healthy        BA
# 234497               NaN          7-8 hours       Moderate    B.Tech
#
#        have_you_ever_had_suicidal_thoughts_?  work/study_hours  \
# id
# 140703                                   Yes              10.0
# 140708                                    No               8.0
# 140719                                    No              11.0
# 140720                                   Yes              10.0
# 140721                                   Yes              11.0
# ...                                      ...               ...
# 234485                                   Yes              12.0
# 234490                                    No               2.0
# 234493                                   Yes               8.0
# 234494                                   Yes               9.0
# 234497                                    No               7.0
#
#         financial_stress family_history_of_mental_illness
# id
# 140703               4.0                               No
# 140708               1.0                              Yes
# 140719               3.0                              Yes
# 140720               4.0                              Yes
# 140721               5.0                               No
# ...                  ...                              ...
# 234485               5.0                              Yes
# 234490               2.0                              Yes
# 234493               2.0                              Yes
# 234494               2.0                               No
# 234497               1.0                               No
#
# [18778 rows x 18 columns]

# %%
test.loc[test['working_professional_or_student'] == "Student", 'work_pressure'] = test.loc[test['working_professional_or_student'] == "Student", 'work_pressure'].fillna(0.0)

# %%
test[test['work_pressure'].isna()]
# Out:
#            name  gender   age         city working_professional_or_student  \
# id
# 145631     Tina  Female  18.0     Srinagar            Working Professional
# 149705    Anand    Male  18.0  Vasai-Virar            Working Professional
# 160926   Himani  Female  19.0       Rajkot            Working Professional
# 171833    Sanya  Female  33.0      Kolkata            Working Professional
# 172498    Janvi  Female  28.0       Mumbai            Working Professional
# 174747   Saanvi  Female  50.0        Thane            Working Professional
# 181776      Ila  Female  52.0       Kanpur            Working Professional
# 189676  Tanisha  Female  37.0        Thane            Working Professional
# 190034     Vani  Female  19.0         Pune            Working Professional
# 210348     Yash    Male  39.0       Bhopal            Working Professional
#
#        profession  academic_pressure  work_pressure  cgpa  study_satisfaction  \
# id
# 145631        NaN                2.0            NaN  8.04                 5.0
# 149705        NaN                0.0            NaN   NaN                 NaN
# 160926        NaN                0.0            NaN   NaN                 NaN
# 171833        NaN                0.0            NaN  9.88                 5.0
# 172498        NaN                0.0            NaN   NaN                 NaN
# 174747        NaN                0.0            NaN   NaN                 NaN
# 181776        NaN                0.0            NaN   NaN                 NaN
# 189676        NaN                0.0            NaN   NaN                 NaN
# 190034        NaN                2.0            NaN   NaN                 4.0
# 210348        NaN                0.0            NaN   NaN                 NaN
#
#         job_satisfaction     sleep_duration dietary_habits    degree  \
# id
# 145631               NaN  More than 8 hours      Unhealthy  Class 12
# 149705               2.0  Less than 5 hours      Unhealthy  Class 12
# 160926               2.0  Less than 5 hours       Moderate  Class 12
# 171833               NaN  More than 8 hours        Healthy       MCA
# 172498               NaN          5-6 hours      Unhealthy       BCA
# 174747               NaN  Less than 5 hours      Unhealthy  Class 12
# 181776               2.0          7-8 hours      Unhealthy   M.Pharm
# 189676               NaN  Less than 5 hours       Moderate       LLB
# 190034               NaN  Less than 5 hours       Moderate  Class 12
# 210348               3.0  Less than 5 hours       Moderate  Class 12
#
#        have_you_ever_had_suicidal_thoughts_?  work/study_hours  \
# id
# 145631                                   Yes               6.0
# 149705                                   Yes               9.0
# 160926                                   Yes               0.0
# 171833                                   Yes              11.0
# 172498                                   Yes               8.0
# 174747                                   Yes               2.0
# 181776                                   Yes               3.0
# 189676                                   Yes               0.0
# 190034                                   Yes               2.0
# 210348                                   Yes               4.0
#
#         financial_stress family_history_of_mental_illness
# id
# 145631               4.0                               No
# 149705               4.0                               No
# 160926               5.0                              Yes
# 171833               1.0                              Yes
# 172498               4.0                               No
# 174747               5.0                               No
# 181776               3.0                               No
# 189676               2.0                              Yes
# 190034               2.0                               No
# 210348               2.0                               No

# %%
test.loc[test['working_professional_or_student'] == "Working Professional", 'work_pressure'] = test.loc[test['working_professional_or_student'] == "Working Professional", 'work_pressure'].fillna(test['work_pressure'].mean())

# %%
test[test['study_satisfaction'].isna()]
# Out:
#            name  gender   age           city working_professional_or_student  \
# id
# 140700   Shivam    Male  53.0  Visakhapatnam            Working Professional
# 140701    Sanya  Female  58.0        Kolkata            Working Professional
# 140702     Yash    Male  53.0         Jaipur            Working Professional
# 140704  Shaurya    Male  47.0         Kalyan            Working Professional
# 140705   Kartik    Male  29.0         Mumbai            Working Professional
# ...         ...     ...   ...            ...                             ...
# 234492   Advait    Male  23.0          Delhi            Working Professional
# 234495     Zoya  Female  49.0         Jaipur            Working Professional
# 234496    Shlok    Male  29.0      Ahmedabad            Working Professional
# 234498   Eshita  Female  23.0         Kalyan            Working Professional
# 234499    Gauri  Female  43.0       Varanasi            Working Professional
#
#                     profession  academic_pressure  work_pressure  cgpa  \
# id
# 140700                   Judge                0.0            2.0   NaN
# 140701  Educational Consultant                0.0            2.0   NaN
# 140702                 Teacher                0.0            4.0   NaN
# 140704                 Teacher                0.0            5.0   NaN
# 140705        Customer Support                0.0            2.0   NaN
# ...                        ...                ...            ...   ...
# 234492              Consultant                0.0            2.0   NaN
# 234495                   Pilot                0.0            3.0   NaN
# 234496                   Pilot                0.0            5.0   NaN
# 234498       Marketing Manager                0.0            4.0   NaN
# 234499  Educational Consultant                0.0            5.0   NaN
#
#         study_satisfaction  job_satisfaction     sleep_duration  \
# id
# 140700                 NaN               5.0  Less than 5 hours
# 140701                 NaN               4.0  Less than 5 hours
# 140702                 NaN               1.0          7-8 hours
# 140704                 NaN               5.0          7-8 hours
# 140705                 NaN               3.0  More than 8 hours
# ...                    ...               ...                ...
# 234492                 NaN               3.0  Less than 5 hours
# 234495                 NaN               5.0  Less than 5 hours
# 234496                 NaN               1.0          7-8 hours
# 234498                 NaN               2.0          5-6 hours
# 234499                 NaN               2.0  More than 8 hours
#
#        dietary_habits  degree have_you_ever_had_suicidal_thoughts_?  \
# id
# 140700       Moderate     LLB                                    No
# 140701       Moderate    B.Ed                                    No
# 140702       Moderate  B.Arch                                   Yes
# 140704       Moderate     BCA                                   Yes
# 140705       Moderate   B.Com                                    No
# ...               ...     ...                                   ...
# 234492       Moderate   B.Com                                   Yes
# 234495       Moderate     BSc                                   Yes
# 234496       Moderate      BE                                   Yes
# 234498        Healthy      BA                                   Yes
# 234499        Healthy    B.Ed                                    No
#
#         work/study_hours  financial_stress family_history_of_mental_illness
# id
# 140700               9.0               3.0                              Yes
# 140701               6.0               4.0                               No
# 140702              12.0               4.0                               No
# 140704               3.0               4.0                               No
# 140705               3.0               2.0                              Yes
# ...                  ...               ...                              ...
# 234492              12.0               4.0                               No
# 234495               2.0               2.0                              Yes
# 234496              11.0               3.0                              Yes
# 234498               7.0               5.0                              Yes
# 234499              11.0               2.0                               No
#
# [75033 rows x 18 columns]

# %%
test.loc[test['working_professional_or_student'] == "Working Professional", 'study_satisfaction'] = test.loc[test['working_professional_or_student'] == "Working Professional", 'study_satisfaction'].fillna(0.0)
test.loc[test['working_professional_or_student'] == "Student", 'study_satisfaction'] = test.loc[test['working_professional_or_student'] == "Student", 'study_satisfaction'].fillna(test['study_satisfaction'].mean())

# %%
test['study_satisfaction'].isna().sum()
# Out:
# 0

# %%
test[test['job_satisfaction'].isna()]
# Out:
#             name  gender   age           city working_professional_or_student  \
# id
# 140703    Nalini  Female  23.0         Rajkot                         Student
# 140708     Navya  Female  21.0          Surat                         Student
# 140719     Kiran    Male  28.0        Lucknow                         Student
# 140720     Rashi  Female  26.0      Ghaziabad                         Student
# 140721     Manan    Male  32.0  Visakhapatnam                         Student
# ...          ...     ...   ...            ...                             ...
# 234485    Ishaan    Male  33.0           Agra                         Student
# 234490  Abhishek    Male  19.0         Nashik                         Student
# 234493      Aohi  Female  29.0       Vadodara                         Student
# 234494     Shlok    Male  33.0         Nashik                         Student
# 234497     Rishi    Male  24.0  Visakhapatnam                         Student
#
#        profession  academic_pressure  work_pressure  cgpa  study_satisfaction  \
# id
# 140703    Student                5.0            0.0  6.84                 1.0
# 140708    Student                1.0            0.0  7.39                 3.0
# 140719    Student                5.0            0.0  6.03                 3.0
# 140720    Student                3.0            0.0  8.63                 5.0
# 140721    Student                3.0            0.0  8.61                 1.0
# ...           ...                ...            ...   ...                 ...
# 234485    Student                5.0            0.0  5.74                 2.0
# 234490    Student                4.0            0.0  8.96                 3.0
# 234493    Student                2.0            0.0  5.58                 5.0
# 234494    Student                1.0            0.0  7.92                 2.0
# 234497    Student                1.0            0.0  7.51                 4.0
#
#         job_satisfaction     sleep_duration dietary_habits    degree  \
# id
# 140703               NaN  More than 8 hours       Moderate       BSc
# 140708               NaN  Less than 5 hours        Healthy       BBA
# 140719               NaN          7-8 hours       Moderate        MA
# 140720               NaN  More than 8 hours       Moderate       BBA
# 140721               NaN  Less than 5 hours       Moderate      M.Ed
# ...                  ...                ...            ...       ...
# 234485               NaN          7-8 hours       Moderate     B.Com
# 234490               NaN          7-8 hours      Unhealthy  Class 12
# 234493               NaN  More than 8 hours        Healthy  Class 12
# 234494               NaN  More than 8 hours        Healthy        BA
# 234497               NaN          7-8 hours       Moderate    B.Tech
#
#        have_you_ever_had_suicidal_thoughts_?  work/study_hours  \
# id
# 140703                                   Yes              10.0
# 140708                                    No               8.0
# 140719                                    No              11.0
# 140720                                   Yes              10.0
# 140721                                   Yes              11.0
# ...                                      ...               ...
# 234485                                   Yes              12.0
# 234490                                    No               2.0
# 234493                                   Yes               8.0
# 234494                                   Yes               9.0
# 234497                                    No               7.0
#
#         financial_stress family_history_of_mental_illness
# id
# 140703               4.0                               No
# 140708               1.0                              Yes
# 140719               3.0                              Yes
# 140720               4.0                              Yes
# 140721               5.0                               No
# ...                  ...                              ...
# 234485               5.0                              Yes
# 234490               2.0                              Yes
# 234493               2.0                              Yes
# 234494               2.0                               No
# 234497               1.0                               No
#
# [18774 rows x 18 columns]

# %%
test.loc[test['working_professional_or_student'] == "Student", 'job_satisfaction'] = test.loc[test['working_professional_or_student'] == "Student", 'job_satisfaction'].fillna(0.0)
test.loc[test['working_professional_or_student'] == "Working Professional", 'job_satisfaction'] = test.loc[test['working_professional_or_student'] == "Working Professional", 'job_satisfaction'].fillna(test['job_satisfaction'].mean())

# %%
# test.dropna(subset=['profession', 'dietary_habits','degree','financial_stress'], inplace=True)

# %%
test['age']=test['age'].astype('int')

# %%
def VC(col):
    for c in col:
        print(test[c].value_counts())
        print("\t  = = = = = = = = = = = = = = = = = = = \t")

# %%
VC(['city','working_professional_or_student','profession','dietary_habits','sleep_duration','degree','have_you_ever_had_suicidal_thoughts_?'])
# Out:
# city
# Kalyan         4387
# Vasai-Virar    3897
# Patna          3888
# Kolkata        3726
# Ahmedabad      3677
#                ...
# Vaikot            1
# Abhinav           1
# Rolkata           1
# Ghopal            1
# No.12             1
# Name: count, Length: 68, dtype: int64
# 	  = = = = = = = = = = = = = = = = = = =
# working_professional_or_student
# Working Professional    75028
# Student                 18772
# Name: count, dtype: int64
# 	  = = = = = = = = = = = = = = = = = = =
# profession
# Student            18754
# Teacher            16385
# Content Writer      5187
# Architect           2982
# Consultant          2920
#                    ...
# Surgeon                1
# No                     1
# Unveil                 1
# City Consultant        1
# M.Pharm                1
# Name: count, Length: 64, dtype: int64
# 	  = = = = = = = = = = = = = = = = = = =
# dietary_habits
# Moderate        33018
# Unhealthy       30786
# Healthy         29966
# No                  6
# More Healthy        2
# Indoor              1
# Prachi              1
# Male                1
# Less Healthy        1
# Mealy               1
# Resistant           1
# MCA                 1
# 5 Healthy           1
# Academic            1
# Educational         1
# Soham               1
# 5 Unhealthy         1
# Vivaan              1
# Raghav              1
# 1.0                 1
# Naina               1
# Kolkata             1
# Name: count, dtype: int64
# 	  = = = = = = = = = = = = = = = = = = =
# sleep_duration
# Less than 5 hours                      25661
# 7-8 hours                              24491
# More than 8 hours                      22190
# 5-6 hours                              21404
# 6-7 hours                                  7
# 8-9 hours                                  6
# 4-5 hours                                  6
# 2-3 hours                                  4
# 3-4 hours                                  3
# 9-5                                        2
# 9-5 hours                                  2
# 1-2 hours                                  2
# 4-6 hours                                  2
# Meerut                                     2
# 1-6 hours                                  2
# Unhealthy                                  1
# Vivan                                      1
# 60-65 hours                                1
# 0                                          1
# 8-89 hours                                 1
# Have_you_ever_had_suicidal_thoughts        1
# than 5 hours                               1
# 9-6 hours                                  1
# 10-6 hours                                 1
# 20-21 hours                                1
# 6 hours                                    1
# 1-3 hours                                  1
# 50-75 hours                                1
# 9-11 hours                                 1
# 9-10 hours                                 1
# 3-6 hours                                  1
# Name: count, dtype: int64
# 	  = = = = = = = = = = = = = = = = = = =
# degree
# Class 12    9812
# B.Ed        7762
# B.Arch      6037
# B.Com       5439
# B.Pharm     3987
#             ...
# 20             1
# Banchal        1
# M.             1
# K.Ed           1
# BHCA           1
# Name: count, Length: 87, dtype: int64
# 	  = = = = = = = = = = = = = = = = = = =
# have_you_ever_had_suicidal_thoughts_?
# No     47375
# Yes    46425
# Name: count, dtype: int64
# 	  = = = = = = = = = = = = = = = = = = =

# %%
# city_counts = test['city'].value_counts()
# threshold = 10
# cities_to_keep = city_counts[city_counts > threshold].index
# test = test[test['city'].isin(cities_to_keep)]

# %%
# degree_counts = test['degree'].value_counts()
# threshold = 10
# Degree_to_keep = degree_counts[degree_counts > threshold].index
# test = test[test['degree'].isin(Degree_to_keep)]

# %%
# profession_counts = test['profession'].value_counts()
# threshold = 10
# profession_to_keep = profession_counts[profession_counts > threshold].index
# test = test[test['profession'].isin(profession_to_keep)]

# %%
# Cleaning `sleep_duration`
# Define a map to consolidate ranges
sleep_map = {
    'Less than 5 hours': '0-5 hours',
    'More than 8 hours': '8+ hours',
    '3-4 hours': '0-5 hours',
    '5-6 hours': '5-6 hours',
    '7-8 hours': '7-8 hours',
    # Add more mappings as needed
}
test['sleep_duration'] = test['sleep_duration'].replace(sleep_map)

valid_sleep = ['0-5 hours', '8+ hours', '5-6 hours','7-8 hours']
test['sleep_duration'] = test['sleep_duration'].where(test['sleep_duration'].isin(valid_sleep))

# %%
# Cleaning `dietary_habits`
# Drop unrelated or incorrect entries
valid_diet = ['Healthy', 'Unhealthy', 'Moderate']
test['dietary_habits'] = test['dietary_habits'].where(test['dietary_habits'].isin(valid_diet))

# %%
test.head()
# Out:
#            name  gender  age           city working_professional_or_student  \
# id
# 140700   Shivam    Male   53  Visakhapatnam            Working Professional
# 140701    Sanya  Female   58        Kolkata            Working Professional
# 140702     Yash    Male   53         Jaipur            Working Professional
# 140703   Nalini  Female   23         Rajkot                         Student
# 140704  Shaurya    Male   47         Kalyan            Working Professional
#
#                     profession  academic_pressure  work_pressure  cgpa  \
# id
# 140700                   Judge                0.0            2.0   NaN
# 140701  Educational Consultant                0.0            2.0   NaN
# 140702                 Teacher                0.0            4.0   NaN
# 140703                 Student                5.0            0.0  6.84
# 140704                 Teacher                0.0            5.0   NaN
#
#         study_satisfaction  job_satisfaction sleep_duration dietary_habits  \
# id
# 140700                 0.0               5.0      0-5 hours       Moderate
# 140701                 0.0               4.0      0-5 hours       Moderate
# 140702                 0.0               1.0      7-8 hours       Moderate
# 140703                 1.0               0.0       8+ hours       Moderate
# 140704                 0.0               5.0      7-8 hours       Moderate
#
#         degree have_you_ever_had_suicidal_thoughts_?  work/study_hours  \
# id
# 140700     LLB                                    No               9.0
# 140701    B.Ed                                    No               6.0
# 140702  B.Arch                                   Yes              12.0
# 140703     BSc                                   Yes              10.0
# 140704     BCA                                   Yes               3.0
#
#         financial_stress family_history_of_mental_illness
# id
# 140700               3.0                              Yes
# 140701               4.0                               No
# 140702               4.0                               No
# 140703               4.0                               No
# 140704               4.0                               No

# %%
# test['sleep_duration'].dropna(inplace = True)

# %%
test[test['sleep_duration'].isna()]
# Out:
#             name  gender  age           city working_professional_or_student  \
# id
# 141223      Vani  Female   38       Varanasi            Working Professional
# 144293     Rajat    Male   45          Delhi            Working Professional
# 145313     Rupal  Female   46       Varanasi            Working Professional
# 149601      Rhea  Female   54          Patna            Working Professional
# 153512      Anvi  Female   33    Vasai-Virar                         Student
# 156298      Ansh    Male   38    Vasai-Virar            Working Professional
# 157107   Aanchal  Female   27       Srinagar            Working Professional
# 159769    Eshita  Female   20          Surat                         Student
# 159837     Samar    Male   51          Thane            Working Professional
# 161326  Aaradhya  Female   28         Bhopal            Working Professional
# 162476    Shoham    Male   28      Ahmedabad                         Student
# 162858    Vivaan    Male   22           Agra            Working Professional
# 162859     Kriti  Female   53      Faridabad            Working Professional
# 167320     Anand    Male   24      Ahmedabad                         Student
# 167445     Sanya  Female   56          Surat            Working Professional
# 167851      Isha  Female   36       Ludhiana            Working Professional
# 170027     Rupal  Female   19       Vadodara            Working Professional
# 170414      Vani  Female   46       Varanasi            Working Professional
# 173003   Krishna    Male   21       Vadodara                         Student
# 174090       Ira  Female   18        Kolkata                         Student
# 175601   Aanchal  Female   22       Srinagar            Working Professional
# 176887     Anika  Female   38          Patna            Working Professional
# 178728   Bhavesh    Male   39         Jaipur            Working Professional
# 180882    Prachi    Male   35         Meerut            Working Professional
# 181222       Jai    Male   49        Kolkata            Working Professional
# 181965     Anaya  Female   28    Vasai-Virar            Working Professional
# 182518    Chhavi  Female   46       Vadodara            Working Professional
# 186267   Pratham    Male   59  Visakhapatnam            Working Professional
# 188445     Rupak    Male   39       Srinagar            Working Professional
# 188767    Vedant    Male   45       Ludhiana            Working Professional
# 191510    Tushar    Male   56       Ludhiana            Working Professional
# 192124    Raghav    Male   41           Pune            Working Professional
# 192902    Tushar    Male   50         Kanpur            Working Professional
# 194782    Saanvi  Female   28       Srinagar                         Student
# 198721    Armaan    Male   49         Kanpur            Working Professional
# 199409    Armaan    Male   22      Bangalore            Working Professional
# 202031     Vidya  Female   57         Bhopal            Working Professional
# 202669    Advait    Male   41         Bhopal            Working Professional
# 207772    Eshita  Female   52         Nagpur            Working Professional
# 208316     Aarti  Female   50       Srinagar            Working Professional
# 209657   Krishna    Male   45        Chennai            Working Professional
# 210094     Aditi  Female   29           Pune            Working Professional
# 210475   Hrithik    Male   50        Kolkata            Working Professional
# 211988     Kriti  Female   46         Nagpur            Working Professional
# 213415    Vikram    Male   28      Hyderabad                         Student
# 215850      Tara  Female   34    Vasai-Virar            Working Professional
# 216846    Yogesh    Male   27       Ludhiana                         Student
# 217127    Vivaan    Male   47         Rajkot            Working Professional
# 228131    Tushar    Male   41      Ahmedabad            Working Professional
# 228250     Gagan    Male   29        Chennai                         Student
# 229244    Aditya    Male   31      Hyderabad            Working Professional
#
#                  profession  academic_pressure  work_pressure  cgpa  \
# id
# 141223               Lawyer                0.0            1.0   NaN
# 144293          Electrician                0.0            4.0   NaN
# 145313           Consultant                0.0            1.0   NaN
# 149601       Content Writer                0.0            3.0   NaN
# 153512              Student                3.0            0.0  9.97
# 156298       Content Writer                0.0            4.0   NaN
# 157107     Graphic Designer                0.0            4.0   NaN
# 159769              Student                1.0            0.0  8.63
# 159837                  NaN                0.0            4.0   NaN
# 161326              Teacher                0.0            5.0   NaN
# 162476              Student                4.0            0.0  6.02
# 162858    Investment Banker                0.0            4.0   NaN
# 162859       Content Writer                0.0            2.0   NaN
# 167320              Student                2.0            0.0  8.21
# 167445              Teacher                0.0            1.0   NaN
# 167851       UX/UI Designer                0.0            1.0   NaN
# 170027                  NaN                0.0            5.0   NaN
# 170414     Digital Marketer                0.0            4.0   NaN
# 173003              Student                3.0            0.0  7.88
# 174090              Student                2.0            0.0  7.79
# 175601       Content Writer                0.0            2.0   NaN
# 176887               Doctor                0.0            1.0   NaN
# 178728              Teacher                0.0            5.0   NaN
# 180882     Graphic Designer                0.0            2.0   NaN
# 181222      Sales Executive                0.0            2.0   NaN
# 181965              Teacher                0.0            4.0   NaN
# 182518              Teacher                0.0            4.0   NaN
# 186267    Marketing Manager                0.0            4.0   NaN
# 188445    Financial Analyst                0.0            4.0   NaN
# 188767              Teacher                0.0            4.0   NaN
# 191510              Teacher                0.0            1.0   NaN
# 192124              Manager                0.0            5.0   NaN
# 192902      Sales Executive                0.0            5.0   NaN
# 194782              Student                5.0            0.0  6.42
# 198721     Business Analyst                0.0            2.0   NaN
# 199409                Judge                0.0            4.0   NaN
# 202031               Doctor                0.0            2.0   NaN
# 202669               Doctor                0.0            2.0   NaN
# 207772           HR Manager                0.0            2.0   NaN
# 208316              Plumber                0.0            1.0   NaN
# 209657     Digital Marketer                0.0            3.0   NaN
# 210094    Travel Consultant                0.0            3.0   NaN
# 210475              Teacher                0.0            2.0   NaN
# 211988              Plumber                0.0            3.0   NaN
# 213415              Student                4.0            0.0  8.65
# 215850              Teacher                0.0            3.0   NaN
# 216846              Student                3.0            0.0  7.52
# 217127              Plumber                0.0            3.0   NaN
# 228131                  NaN                0.0            2.0   NaN
# 228250              Student                2.0            0.0  9.94
# 229244  Mechanical Engineer                0.0            2.0   NaN
#
#         study_satisfaction  job_satisfaction sleep_duration dietary_habits  \
# id
# 141223                 0.0               4.0            NaN      Unhealthy
# 144293                 0.0               4.0            NaN      Unhealthy
# 145313                 0.0               4.0            NaN       Moderate
# 149601                 0.0               3.0            NaN       Moderate
# 153512                 1.0               0.0            NaN      Unhealthy
# 156298                 0.0               1.0            NaN      Unhealthy
# 157107                 0.0               1.0            NaN        Healthy
# 159769                 5.0               0.0            NaN        Healthy
# 159837                 0.0               5.0            NaN      Unhealthy
# 161326                 0.0               1.0            NaN      Unhealthy
# 162476                 2.0               0.0            NaN      Unhealthy
# 162858                 0.0               1.0            NaN       Moderate
# 162859                 0.0               4.0            NaN        Healthy
# 167320                 4.0               0.0            NaN       Moderate
# 167445                 0.0               2.0            NaN       Moderate
# 167851                 0.0               4.0            NaN        Healthy
# 170027                 0.0               1.0            NaN        Healthy
# 170414                 0.0               4.0            NaN        Healthy
# 173003                 1.0               0.0            NaN      Unhealthy
# 174090                 5.0               0.0            NaN        Healthy
# 175601                 0.0               1.0            NaN        Healthy
# 176887                 0.0               1.0            NaN       Moderate
# 178728                 0.0               4.0            NaN        Healthy
# 180882                 0.0               1.0            NaN      Unhealthy
# 181222                 0.0               5.0            NaN        Healthy
# 181965                 0.0               2.0            NaN       Moderate
# 182518                 0.0               3.0            NaN        Healthy
# 186267                 0.0               5.0            NaN        Healthy
# 188445                 0.0               3.0            NaN        Healthy
# 188767                 0.0               1.0            NaN      Unhealthy
# 191510                 0.0               2.0            NaN      Unhealthy
# 192124                 0.0               4.0            NaN        Healthy
# 192902                 0.0               3.0            NaN        Healthy
# 194782                 2.0               0.0            NaN        Healthy
# 198721                 0.0               2.0            NaN      Unhealthy
# 199409                 0.0               1.0            NaN       Moderate
# 202031                 0.0               3.0            NaN      Unhealthy
# 202669                 0.0               3.0            NaN       Moderate
# 207772                 0.0               2.0            NaN        Healthy
# 208316                 0.0               5.0            NaN        Healthy
# 209657                 0.0               2.0            NaN        Healthy
# 210094                 0.0               5.0            NaN      Unhealthy
# 210475                 0.0               1.0            NaN      Unhealthy
# 211988                 0.0               5.0            NaN      Unhealthy
# 213415                 5.0               0.0            NaN       Moderate
# 215850                 0.0               2.0            NaN      Unhealthy
# 216846                 1.0               0.0            NaN       Moderate
# 217127                 0.0               5.0            NaN       Moderate
# 228131                 0.0               5.0            NaN      Unhealthy
# 228250                 4.0               0.0            NaN       Moderate
# 229244                 0.0               3.0            NaN        Healthy
#
#           degree have_you_ever_had_suicidal_thoughts_?  work/study_hours  \
# id
# 141223       LLM                                    No               1.0
# 144293       PhD                                    No               0.0
# 145313        BE                                   Yes               5.0
# 149601      M.Ed                                    No               0.0
# 153512       BSc                                   Yes               0.0
# 156298       BSc                                   Yes               6.0
# 157107       BSc                                   Yes               6.0
# 159769  Class 12                                   Yes               7.0
# 159837  Class 12                                    No               0.0
# 161326      MBBS                                   Yes              11.0
# 162476    B.Arch                                   Yes              11.0
# 162858       MBA                                   Yes               3.0
# 162859        MA                                   Yes               3.0
# 167320  Class 12                                   Yes               8.0
# 167445       LLB                                   Yes              11.0
# 167851       PhD                                   Yes              12.0
# 170027  Class 12                                   Yes              11.0
# 170414        BA                                   Yes               2.0
# 173003       BHM                                   Yes              10.0
# 174090  Class 12                                    No               1.0
# 175601      B.Ed                                   Yes               9.0
# 176887   M.Pharm                                   Yes               5.0
# 178728    M.Tech                                    No               1.0
# 180882        BE                                    No               6.0
# 181222       MBA                                   Yes               3.0
# 181965       LLM                                   Yes              10.0
# 182518       BBA                                   Yes              11.0
# 186267        BA                                   Yes               3.0
# 188445     M.Com                                   Yes               1.0
# 188767       LLM                                    No               0.0
# 191510     B.Com                                   Yes               1.0
# 192124       BHM                                    No               9.0
# 192902       BBA                                   Yes               1.0
# 194782        BA                                   Yes              11.0
# 198721        ME                                    No               2.0
# 199409       LLM                                   Yes               5.0
# 202031   M.Pharm                                   Yes               7.0
# 202669   B.Pharm                                    No               4.0
# 207772       MBA                                   Yes               8.0
# 208316       BSc                                   Yes               2.0
# 209657        BA                                    No               3.0
# 210094       MHM                                    No               5.0
# 210475      B.Ed                                   Yes               7.0
# 211988       BSc                                   Yes              10.0
# 213415      B.Ed                                    No              12.0
# 215850      MBBS                                   Yes              10.0
# 216846       BBA                                    No               5.0
# 217127       BSc                                    No               3.0
# 228131  Class 12                                   Yes              10.0
# 228250       BSc                                   Yes               1.0
# 229244       PhD                                    No               2.0
#
#         financial_stress family_history_of_mental_illness
# id
# 141223               4.0                               No
# 144293               1.0                               No
# 145313               5.0                              Yes
# 149601               5.0                              Yes
# 153512               2.0                              Yes
# 156298               4.0                              Yes
# 157107               5.0                              Yes
# 159769               2.0                              Yes
# 159837               1.0                              Yes
# 161326               4.0                              Yes
# 162476               3.0                               No
# 162858               2.0                              Yes
# 162859               5.0                               No
# 167320               2.0                              Yes
# 167445               2.0                               No
# 167851               3.0                              Yes
# 170027               2.0                               No
# 170414               4.0                              Yes
# 173003               2.0                               No
# 174090               1.0                               No
# 175601               4.0                              Yes
# 176887               4.0                               No
# 178728               1.0                               No
# 180882               1.0                              Yes
# 181222               2.0                               No
# 181965               4.0                              Yes
# 182518               2.0                               No
# 186267               4.0                               No
# 188445               5.0                               No
# 188767               3.0                               No
# 191510               4.0                               No
# 192124               1.0                              Yes
# 192902               4.0                               No
# 194782               2.0                               No
# 198721               5.0                              Yes
# 199409               3.0                               No
# 202031               1.0                              Yes
# 202669               3.0                               No
# 207772               2.0                              Yes
# 208316               2.0                               No
# 209657               1.0                               No
# 210094               4.0                              Yes
# 210475               5.0                               No
# 211988               2.0                              Yes
# 213415               2.0                              Yes
# 215850               5.0                               No
# 216846               5.0                              Yes
# 217127               1.0                               No
# 228131               4.0                               No
# 228250               2.0                               No
# 229244               4.0                               No

# %%
test1 =test.copy()

# %%
col = ['dietary_habits','gender','working_professional_or_student','profession','degree','city','sleep_duration','have_you_ever_had_suicidal_thoughts_?','family_history_of_mental_illness']


def label_encode(test, column_name):
    le = LabelEncoder()
    for col in column_name:
        test[col] = le.fit_transform(test[col])
    return test

# %%
label_encode(test,col)
# Out:
#            name  gender  age  city  working_professional_or_student  \
# id
# 140700   Shivam       1   53    67                                1
# 140701    Sanya       0   58    25                                1
# 140702     Yash       1   53    21                                1
# 140703   Nalini       0   23    47                                0
# 140704  Shaurya       1   47    22                                1
# ...         ...     ...  ...   ...                              ...
# 234495     Zoya       0   49    21                                1
# 234496    Shlok       1   29     3                                1
# 234497    Rishi       1   24    67                                0
# 234498   Eshita       0   23    22                                1
# 234499    Gauri       0   43    62                                1
#
#         profession  academic_pressure  work_pressure  cgpa  \
# id
# 140700          27                0.0            2.0   NaN
# 140701          19                0.0            2.0   NaN
# 140702          56                0.0            4.0   NaN
# 140703          53                5.0            0.0  6.84
# 140704          56                0.0            5.0   NaN
# ...            ...                ...            ...   ...
# 234495          44                0.0            3.0   NaN
# 234496          44                0.0            5.0   NaN
# 234497          53                1.0            0.0  7.51
# 234498          38                0.0            4.0   NaN
# 234499          19                0.0            5.0   NaN
#
#         study_satisfaction  job_satisfaction  sleep_duration  dietary_habits  \
# id
# 140700                 0.0               5.0               0               1
# 140701                 0.0               4.0               0               1
# 140702                 0.0               1.0               2               1
# 140703                 1.0               0.0               3               1
# 140704                 0.0               5.0               2               1
# ...                    ...               ...             ...             ...
# 234495                 0.0               5.0               0               1
# 234496                 0.0               1.0               2               1
# 234497                 4.0               0.0               2               1
# 234498                 0.0               2.0               1               0
# 234499                 0.0               2.0               3               0
#
#         degree  have_you_ever_had_suicidal_thoughts_?  work/study_hours  \
# id
# 140700      53                                      0               9.0
# 140701      16                                      0               6.0
# 140702      12                                      1              12.0
# 140703      35                                      1              10.0
# 140704      28                                      1               3.0
# ...        ...                                    ...               ...
# 234495      35                                      1               2.0
# 234496      29                                      1              11.0
# 234497      23                                      0               7.0
# 234498      25                                      1               7.0
# 234499      16                                      0              11.0
#
#         financial_stress  family_history_of_mental_illness
# id
# 140700               3.0                                 1
# 140701               4.0                                 0
# 140702               4.0                                 0
# 140703               4.0                                 0
# 140704               4.0                                 0
# ...                  ...                               ...
# 234495               2.0                                 1
# 234496               3.0                                 1
# 234497               1.0                                 0
# 234498               5.0                                 1
# 234499               2.0                                 0
#
# [93800 rows x 18 columns]

# %%
#!pip install pandas==1.4.0

# %%
# def one_hot_encode_multiple_columns(df, columns):
#     # Replace 'sparse' with 'sparse_output'
#     ohe = OneHotEncoder(sparse_output=False, drop='first')
#     # Fit and transform the specified columns
#     encoded = ohe.fit_transform(df[columns])
#     # Create a DataFrame with the encoded columns
#     encoded_df = pd.DataFrame(encoded, columns=ohe.get_feature_names_out(columns))
#     # Concatenate with the original DataFrame and drop the original columns
#     df = pd.concat([df.reset_index(drop=True), encoded_df], axis=1).drop(columns, axis=1)
#     return df

# %%
# For one-hot encoding
# df = one_hot_encode_multiple_columns(df, ['city', 'profession','degree'])

# %% [markdown]
# # Scaling the data

# %%
columns_to_scale = df_copy.columns.difference(['name','depression'])
scaler = StandardScaler()
# Fit and transform the specified columns
df_scaled = scaler.fit_transform(df_copy[columns_to_scale])
df_copy[columns_to_scale] = pd.DataFrame(df_scaled, columns=columns_to_scale, index=df_copy.index)
df_copy.head()
# Out:
#         name    gender       age      city  working_professional_or_student  \
# id
# 0   Aaradhya -1.105766  0.661355  0.000241                         0.517717
# 1      Vivan  0.904350 -1.260907  1.399760                         0.517717
# 2     Yuvraj  0.904350 -0.675871  1.633013                        -1.931557
# 3     Yuvraj  0.904350 -1.595213  0.233494                         0.517717
# 4       Rhea -1.105766 -0.926600 -0.349639                         0.517717
#
#     profession  academic_pressure  work_pressure      cgpa  \
# id
# 0    -1.586476          -0.463995       1.531596       NaN
# 1     0.973695          -0.463995       0.955571       NaN
# 2     0.888356           3.028953      -1.348527  0.895475
# 3     0.973695          -0.463995       1.531596       NaN
# 4    -1.671815          -0.463995      -0.772502       NaN
#
#     study_satisfaction  job_satisfaction  sleep_duration  dietary_habits  \
# id
# 0            -0.459285         -0.197686        1.368983       -1.250727
# 1            -0.459285          0.375582       -1.300393        1.239382
# 2             1.016404         -1.344223       -0.410601       -1.250727
# 3            -0.459285         -0.770955       -1.300393       -0.005673
# 4            -0.459285         -0.770955       -0.410601        1.239382
#
#       degree  have_you_ever_had_suicidal_thoughts_?  work/study_hours  \
# id
# 0  -0.258354                              -0.978341         -1.359133
# 1   0.114893                               1.022138          0.196737
# 2  -1.004850                               1.022138         -0.840510
# 3  -0.631602                               1.022138          0.974672
# 4  -0.631602                               1.022138          0.715360
#
#     financial_stress  family_history_of_mental_illness  depression
# id
# 0          -0.693750                         -0.995189           0
# 1           0.014412                         -0.995189           1
# 2          -1.401912                         -0.995189           1
# 3          -1.401912                          1.004834           1
# 4           0.722575                          1.004834           0

# %% [markdown]
# # Training And Spliting

# %%
df['depression'].value_counts()
# Out:
# depression
# 0    109454
# 1     22231
# Name: count, dtype: int64

# %%
X = df_copy.drop(columns=['name','cgpa','depression'])  # Features
y = df_copy['depression']  # Target variable

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2022)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((105348, 16), (26337, 16), (105348,), (26337,))

# %% [markdown]
# # Modeling

# %%
columns_to_scale = test.columns.difference(['name','cgpa'])

# Fit and transform the specified columns
test_scaled = scaler.fit_transform(test[columns_to_scale])
test[columns_to_scale] = pd.DataFrame(test_scaled, columns=columns_to_scale, index=test.index)
test.head()
# Out:
#            name    gender       age      city  \
# id
# 140700   Shivam  0.910942  1.022988  1.749291
# 140701    Sanya -1.097765  1.426428 -0.384568
# 140702     Yash  0.910942  1.022988 -0.587793
# 140703   Nalini -1.097765 -1.397652  0.733168
# 140704  Shaurya  0.910942  0.538860 -0.536987
#
#         working_professional_or_student  profession  academic_pressure  \
# id
# 140700                         0.500200   -0.559166          -0.448987
# 140701                         0.500200   -0.968569          -0.448987
# 140702                         0.500200    0.924920          -0.448987
# 140703                        -1.999201    0.771393           3.103134
# 140704                         0.500200    0.924920          -0.448987
#
#         work_pressure  cgpa  study_satisfaction  job_satisfaction  \
# id
# 140700      -0.235133   NaN           -0.443263          1.520619
# 140701      -0.235133   NaN           -0.443263          0.942762
# 140702       0.914337   NaN           -0.443263         -0.790810
# 140703      -1.384603  6.84            0.310363         -1.368667
# 140704       1.489072   NaN           -0.443263          1.520619
#
#         sleep_duration  dietary_habits    degree  \
# id
# 140700       -1.296434       -0.011647  0.510629
# 140701       -1.296434       -0.011647 -1.213462
# 140702        0.476758       -0.011647 -1.399850
# 140703        1.363354       -0.011647 -0.328118
# 140704        0.476758       -0.011647 -0.654297
#
#         have_you_ever_had_suicidal_thoughts_?  work/study_hours  \
# id
# 140700                              -0.989923          0.713464
# 140701                              -0.989923         -0.064107
# 140702                               1.010180          1.491035
# 140703                               1.010180          0.972654
# 140704                               1.010180         -0.841677
#
#         financial_stress  family_history_of_mental_illness
# id
# 140700          0.015013                          1.004659
# 140701          0.721928                         -0.995363
# 140702          0.721928                         -0.995363
# 140703          0.721928                         -0.995363
# 140704          0.721928                         -0.995363

# %% [markdown]
# ## Logistic Regression

# %%
# Step 1: Train Logistic Regression model
log_reg = LogisticRegression()
log_reg.fit(X_train, y_train)

# Step 2: Predictions
y_pred = log_reg.predict(X_test)

# Step 3: Model Evaluation
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

# Print the results
print(f"Accuracy: {accuracy:.4f}")
print(f"Confusion Matrix:\n{conf_matrix}")
print(f"Classification Report:\n{class_report}")
# Out:
# Accuracy: 0.9415
# Confusion Matrix:
# [[21295   690]
#  [  852  3500]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.97     21985
#            1       0.84      0.80      0.82      4352
#
#     accuracy                           0.94     26337
#    macro avg       0.90      0.89      0.89     26337
# weighted avg       0.94      0.94      0.94     26337

# %% [markdown]
# test.head(

# %% [markdown]
# ### Testing on Unseen Data "Test"

# %%
test.drop(columns=['name','cgpa'],inplace=True)

y_pred = log_reg.predict(test)

test1['predicted_depression'] = y_pred
test1.head()
# Out:
#            name  gender  age           city working_professional_or_student  \
# id
# 140700   Shivam    Male   53  Visakhapatnam            Working Professional
# 140701    Sanya  Female   58        Kolkata            Working Professional
# 140702     Yash    Male   53         Jaipur            Working Professional
# 140703   Nalini  Female   23         Rajkot                         Student
# 140704  Shaurya    Male   47         Kalyan            Working Professional
#
#                     profession  academic_pressure  work_pressure  cgpa  \
# id
# 140700                   Judge                0.0            2.0   NaN
# 140701  Educational Consultant                0.0            2.0   NaN
# 140702                 Teacher                0.0            4.0   NaN
# 140703                 Student                5.0            0.0  6.84
# 140704                 Teacher                0.0            5.0   NaN
#
#         study_satisfaction  job_satisfaction sleep_duration dietary_habits  \
# id
# 140700                 0.0               5.0      0-5 hours       Moderate
# 140701                 0.0               4.0      0-5 hours       Moderate
# 140702                 0.0               1.0      7-8 hours       Moderate
# 140703                 1.0               0.0       8+ hours       Moderate
# 140704                 0.0               5.0      7-8 hours       Moderate
#
#         degree have_you_ever_had_suicidal_thoughts_?  work/study_hours  \
# id
# 140700     LLB                                    No               9.0
# 140701    B.Ed                                    No               6.0
# 140702  B.Arch                                   Yes              12.0
# 140703     BSc                                   Yes              10.0
# 140704     BCA                                   Yes               3.0
#
#         financial_stress family_history_of_mental_illness  \
# id
# 140700               3.0                              Yes
# 140701               4.0                               No
# 140702               4.0                               No
# 140703               4.0                               No
# 140704               4.0                               No
#
#         predicted_depression
# id
# 140700                     0
# 140701                     0
# 140702                     0
# 140703                     1
# 140704                     0

# %% [markdown]
# ## Decision Tree

# %%
# Decision Tree Model
model = DecisionTreeClassifier(random_state=42)
model.fit(X_train, y_train)

# Predictions and Evaluation
y_pred_dt = model.predict(X_test)
print("Accuracy:", accuracy_score(y_test,y_pred_dt))
conf_matrix = confusion_matrix(y_test, y_pred_dt)
class_report = classification_report(y_test, y_pred_dt)

# Print the results
print(f"Accuracy: {accuracy:.4f}")
print(f"Confusion Matrix:\n{conf_matrix}")
print(f"Classification Report:\n{class_report}")
# Out:
# Accuracy: 0.9084557846375821
# Accuracy: 0.9415
# Confusion Matrix:
# [[20680  1305]
#  [ 1106  3246]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.94     21985
#            1       0.71      0.75      0.73      4352
#
#     accuracy                           0.91     26337
#    macro avg       0.83      0.84      0.84     26337
# weighted avg       0.91      0.91      0.91     26337

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# Random Forest Model
model = RandomForestClassifier(random_state=42)
model.fit(X_train, y_train)

# Predictions and Evaluation
y_pred_Rf = model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred_Rf))
conf_matrix = confusion_matrix(y_test, y_pred_Rf)
class_report = classification_report(y_test, y_pred_Rf)

# Print the results
print(f"Accuracy: {accuracy:.4f}")
print(f"Confusion Matrix:\n{conf_matrix}")
print(f"Classification Report:\n{class_report}")
# Out:
# Accuracy: 0.9411474351672552
# Accuracy: 0.9415
# Confusion Matrix:
# [[21326   659]
#  [  891  3461]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.96     21985
#            1       0.84      0.80      0.82      4352
#
#     accuracy                           0.94     26337
#    macro avg       0.90      0.88      0.89     26337
# weighted avg       0.94      0.94      0.94     26337

# %% [markdown]
# ## Voting Classifier

# %%
LR = LogisticRegression()
Tree = DecisionTreeClassifier()
RF = RandomForestClassifier()
SVM = SVC()
KNN = KNeighborsClassifier()
GB = GradientBoostingClassifier()
AB = AdaBoostClassifier()
LGBM = LGBMClassifier()

# Voting Classifier
model = VotingClassifier(
    estimators=[ ("Decision Tree", Tree),("Logistic Regression", LR) ,("Random Forest", RF),
               ("Support Vector Machine",SVM), ("k-nearest neighbor",KNN), ("Gradient Boosting",GB),
               ("AdaBoost",AB), ("LGBM", LGBM)],
    voting='hard',
)


# Preprocessing of training data, fit model
model.fit(X_train, y_train)

# Preprocessing of validation data, get predictions
prediction = model.predict(X_test)
# Out:
# [LightGBM] [Info] Number of positive: 17879, number of negative: 87469
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.007118 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 213
# [LightGBM] [Info] Number of data points in the train set: 105348, number of used features: 16
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.169714 -> initscore=-1.587658
# [LightGBM] [Info] Start training from score -1.587658

# %%
cm = confusion_matrix(prediction,y_test)
cm
# Out:
# array([[21347,   872],
#        [  638,  3480]])

# %%
sk_report = classification_report(
    digits=2,
    y_true=prediction,
    y_pred=y_test)
print(sk_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.97     22219
#            1       0.80      0.85      0.82      4118
#
#     accuracy                           0.94     26337
#    macro avg       0.89      0.90      0.89     26337
# weighted avg       0.94      0.94      0.94     26337

# %%
# Predict on test data
test_pred = model.predict(test)

# Create submission DataFrame
submission = pd.DataFrame({
    'id': test.index,
    'Depression': test_pred
})

# # Save submission to CSV
submission.to_csv('submission.csv', index=False)

# %% [markdown]
# -----
